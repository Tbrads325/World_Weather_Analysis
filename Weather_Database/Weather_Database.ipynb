# %%
# Import the requests library.
import requests

# Import the API key.
import os
os.chdir("..")
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
coordinates_list = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates_list:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 734

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_des = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country":city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_des})
                          #"Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | dedza
# Processing Record 2 of Set 1 | ola
# Processing Record 3 of Set 1 | san patricio
# Processing Record 4 of Set 1 | saint george
# Processing Record 5 of Set 1 | khatanga
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | busselton
# Processing Record 9 of Set 1 | arawa
# Processing Record 10 of Set 1 | sitka
# Processing Record 11 of Set 1 | jamestown
# Processing Record 12 of Set 1 | cruzeiro do sul
# Processing Record 13 of Set 1 | myski
# Processing Record 14 of Set 1 | mitsamiouli
# Processing Record 15 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 16 of Set 1 | coquimbo
# Processing Record 17 of Set 1 | albany
# Processing Record 18 of Set 1 | sumbe
# Processing Record 19 of Set 1 | yellowknife
# Processing Record 20 of Set 1 | vaini
# Processing Record 21 of Set 1 | saint-philippe
# Processing Record 22 of Set 1 | mataura
# Processing Record 23 of Set 1 | clyde river
# Processing Record 24 of Set 1 | ngunguru
# Processing Record 25 of Set 1 | lorengau
# Processing Record 26 of Set 1 | provideniya
# Processing Record 27 of Set 1 | salvador
# Processing Record 28 of Set 1 | kodiak
# Processing Record 29 of Set 1 | cape town
# Processing Record 30 of Set 1 | xining
# Processing Record 31 of Set 1 | geraldton
# Processing Record 32 of Set 1 | puerto cabezas
# Processing Record 33 of Set 1 | xadani
# City not found. Skipping...
# Processing Record 34 of Set 1 | hithadhoo
# Processing Record 35 of Set 1 | pevek
# Processing Record 36 of Set 1 | rungata
# City not found. Skipping...
# Processing Record 37 of Set 1 | zabol
# Processing Record 38 of Set 1 | isangel
# Processing Record 39 of Set 1 | matagami
# Processing Record 40 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 41 of Set 1 | mollendo
# Processing Record 42 of Set 1 | thompson
# Processing Record 43 of Set 1 | aqtobe
# Processing Record 44 of Set 1 | east london
# Processing Record 45 of Set 1 | pingliang
# Processing Record 46 of Set 1 | north myrtle beach
# Processing Record 47 of Set 1 | vrangel
# Processing Record 48 of Set 1 | new norfolk
# Processing Record 49 of Set 1 | hobyo
# Processing Record 50 of Set 1 | saskylakh
# Processing Record 1 of Set 2 | grand gaube
# Processing Record 2 of Set 2 | omboue
# Processing Record 3 of Set 2 | angoram
# Processing Record 4 of Set 2 | kapaa
# Processing Record 5 of Set 2 | avarua
# Processing Record 6 of Set 2 | bambous virieux
# Processing Record 7 of Set 2 | nicoya
# Processing Record 8 of Set 2 | moultrie
# Processing Record 9 of Set 2 | vardo
# Processing Record 10 of Set 2 | ponta do sol
# Processing Record 11 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 2 | fortuna
# Processing Record 13 of Set 2 | rumoi
# Processing Record 14 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 15 of Set 2 | balkanabat
# Processing Record 16 of Set 2 | ruatoria
# City not found. Skipping...
# Processing Record 17 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 18 of Set 2 | carnarvon
# Processing Record 19 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 20 of Set 2 | tasiilaq
# Processing Record 21 of Set 2 | port elizabeth
# Processing Record 22 of Set 2 | mocambique
# City not found. Skipping...
# Processing Record 23 of Set 2 | vao
# Processing Record 24 of Set 2 | altay
# Processing Record 25 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 26 of Set 2 | barrow
# Processing Record 27 of Set 2 | hermanus
# Processing Record 28 of Set 2 | hilo
# Processing Record 29 of Set 2 | eureka
# Processing Record 30 of Set 2 | asau
# Processing Record 31 of Set 2 | kimberley
# Processing Record 32 of Set 2 | comodoro rivadavia
# Processing Record 33 of Set 2 | tuktoyaktuk
# Processing Record 34 of Set 2 | suda
# Processing Record 35 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 36 of Set 2 | rikitea
# Processing Record 37 of Set 2 | coahuayana
# Processing Record 38 of Set 2 | victoria
# Processing Record 39 of Set 2 | araouane
# Processing Record 40 of Set 2 | ardistan
# City not found. Skipping...
# Processing Record 41 of Set 2 | hobart
# Processing Record 42 of Set 2 | bundaberg
# Processing Record 43 of Set 2 | morrinhos
# Processing Record 44 of Set 2 | jalu
# Processing Record 45 of Set 2 | vila velha
# Processing Record 46 of Set 2 | ancud
# Processing Record 47 of Set 2 | mahebourg
# Processing Record 48 of Set 2 | bengkulu
# Processing Record 49 of Set 2 | shache
# Processing Record 50 of Set 2 | horodnye
# Processing Record 1 of Set 3 | svetlogorsk
# Processing Record 2 of Set 3 | huambo
# Processing Record 3 of Set 3 | komsomolskiy
# Processing Record 4 of Set 3 | egvekinot
# Processing Record 5 of Set 3 | hay river
# Processing Record 6 of Set 3 | luderitz
# Processing Record 7 of Set 3 | chokurdakh
# Processing Record 8 of Set 3 | samarai
# Processing Record 9 of Set 3 | los llanos de aridane
# Processing Record 10 of Set 3 | alice springs
# Processing Record 11 of Set 3 | kanniyakumari
# Processing Record 12 of Set 3 | ribeira grande
# Processing Record 13 of Set 3 | luganville
# Processing Record 14 of Set 3 | lata
# Processing Record 15 of Set 3 | batouri
# Processing Record 16 of Set 3 | sobolevo
# Processing Record 17 of Set 3 | srednekolymsk
# Processing Record 18 of Set 3 | talnakh
# Processing Record 19 of Set 3 | tiksi
# Processing Record 20 of Set 3 | sorland
# Processing Record 21 of Set 3 | upernavik
# Processing Record 22 of Set 3 | lebu
# Processing Record 23 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 24 of Set 3 | dryden
# Processing Record 25 of Set 3 | rwamagana
# Processing Record 26 of Set 3 | bosaso
# Processing Record 27 of Set 3 | dunedin
# Processing Record 28 of Set 3 | nanortalik
# Processing Record 29 of Set 3 | port alfred
# Processing Record 30 of Set 3 | tosham
# Processing Record 31 of Set 3 | starkville
# Processing Record 32 of Set 3 | severo-kurilsk
# Processing Record 33 of Set 3 | innisfail
# Processing Record 34 of Set 3 | petrovsk-zabaykalskiy
# Processing Record 35 of Set 3 | jumilla
# Processing Record 36 of Set 3 | coolum beach
# Processing Record 37 of Set 3 | beipiao
# Processing Record 38 of Set 3 | keffi
# Processing Record 39 of Set 3 | qaanaaq
# Processing Record 40 of Set 3 | baghdad
# Processing Record 41 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 42 of Set 3 | arraial do cabo
# Processing Record 43 of Set 3 | esperance
# Processing Record 44 of Set 3 | nabire
# Processing Record 45 of Set 3 | pailon
# Processing Record 46 of Set 3 | ayni
# Processing Record 47 of Set 3 | bluff
# Processing Record 48 of Set 3 | la ronge
# Processing Record 49 of Set 3 | mar del plata
# Processing Record 50 of Set 3 | rio gallegos
# Processing Record 1 of Set 4 | kruisfontein
# Processing Record 2 of Set 4 | balimo
# City not found. Skipping...
# Processing Record 3 of Set 4 | szamotuly
# Processing Record 4 of Set 4 | iralaya
# Processing Record 5 of Set 4 | orbetello
# Processing Record 6 of Set 4 | atuona
# Processing Record 7 of Set 4 | uyuni
# Processing Record 8 of Set 4 | kidal
# Processing Record 9 of Set 4 | veraval
# Processing Record 10 of Set 4 | kahului
# Processing Record 11 of Set 4 | kushima
# Processing Record 12 of Set 4 | bethel
# Processing Record 13 of Set 4 | puerto ayora
# Processing Record 14 of Set 4 | raymondville
# Processing Record 15 of Set 4 | serabu
# Processing Record 16 of Set 4 | katsuura
# Processing Record 17 of Set 4 | kondagaon
# Processing Record 18 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 19 of Set 4 | saint-augustin
# Processing Record 20 of Set 4 | benjamin constant
# Processing Record 21 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 22 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 23 of Set 4 | sainte-anne-des-monts
# Processing Record 24 of Set 4 | ahipara
# Processing Record 25 of Set 4 | butaritari
# Processing Record 26 of Set 4 | kalanguy
# Processing Record 27 of Set 4 | dikson
# Processing Record 28 of Set 4 | pontianak
# Processing Record 29 of Set 4 | susehri
# Processing Record 30 of Set 4 | nikolskoye
# Processing Record 31 of Set 4 | flinders
# Processing Record 32 of Set 4 | assiniboia
# Processing Record 33 of Set 4 | hervey bay
# Processing Record 34 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 35 of Set 4 | banjar
# Processing Record 36 of Set 4 | port hardy
# Processing Record 37 of Set 4 | morondava
# Processing Record 38 of Set 4 | castro
# Processing Record 39 of Set 4 | talcahuano
# Processing Record 40 of Set 4 | codrington
# Processing Record 41 of Set 4 | georgetown
# Processing Record 42 of Set 4 | aklavik
# Processing Record 43 of Set 4 | yagodnoye
# Processing Record 44 of Set 4 | pangnirtung
# Processing Record 45 of Set 4 | bredasdorp
# Processing Record 46 of Set 4 | burlington
# Processing Record 47 of Set 4 | adrar
# Processing Record 48 of Set 4 | sao filipe
# Processing Record 49 of Set 4 | valley city
# Processing Record 50 of Set 4 | zhigansk
# Processing Record 1 of Set 5 | garowe
# Processing Record 2 of Set 5 | daru
# Processing Record 3 of Set 5 | mabaruma
# Processing Record 4 of Set 5 | magangue
# Processing Record 5 of Set 5 | sug-aksy
# City not found. Skipping...
# Processing Record 6 of Set 5 | taoudenni
# Processing Record 7 of Set 5 | longyearbyen
# Processing Record 8 of Set 5 | guliston
# Processing Record 9 of Set 5 | uchiza
# Processing Record 10 of Set 5 | pedernales
# Processing Record 11 of Set 5 | tallahassee
# Processing Record 12 of Set 5 | bud
# Processing Record 13 of Set 5 | puerto del rosario
# Processing Record 14 of Set 5 | champerico
# Processing Record 15 of Set 5 | rocha
# Processing Record 16 of Set 5 | takoradi
# Processing Record 17 of Set 5 | tessalit
# Processing Record 18 of Set 5 | cooma
# Processing Record 19 of Set 5 | marsh harbour
# Processing Record 20 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 21 of Set 5 | ambilobe
# Processing Record 22 of Set 5 | nouakchott
# Processing Record 23 of Set 5 | fairbanks
# Processing Record 24 of Set 5 | husavik
# Processing Record 25 of Set 5 | acuna
# City not found. Skipping...
# Processing Record 26 of Set 5 | hasaki
# Processing Record 27 of Set 5 | vila do maio
# Processing Record 28 of Set 5 | russell
# Processing Record 29 of Set 5 | salur
# Processing Record 30 of Set 5 | tungkang
# City not found. Skipping...
# Processing Record 31 of Set 5 | kloulklubed
# Processing Record 32 of Set 5 | tabou
# Processing Record 33 of Set 5 | lavrentiya
# Processing Record 34 of Set 5 | san cristobal
# Processing Record 35 of Set 5 | laguna
# Processing Record 36 of Set 5 | pimentel
# Processing Record 37 of Set 5 | inhambane
# Processing Record 38 of Set 5 | preobrazheniye
# Processing Record 39 of Set 5 | astara
# Processing Record 40 of Set 5 | viligili
# City not found. Skipping...
# Processing Record 41 of Set 5 | bay roberts
# Processing Record 42 of Set 5 | atambua
# Processing Record 43 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 44 of Set 5 | jeremie
# Processing Record 45 of Set 5 | kisangani
# Processing Record 46 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 47 of Set 5 | umm lajj
# Processing Record 48 of Set 5 | vestmannaeyjar
# Processing Record 49 of Set 5 | cap malheureux
# Processing Record 50 of Set 5 | poykovskiy
# Processing Record 1 of Set 6 | cheuskiny
# City not found. Skipping...
# Processing Record 2 of Set 6 | duz
# City not found. Skipping...
# Processing Record 3 of Set 6 | windsor
# Processing Record 4 of Set 6 | cacu
# Processing Record 5 of Set 6 | atherton
# Processing Record 6 of Set 6 | sungaipenuh
# Processing Record 7 of Set 6 | narsaq
# Processing Record 8 of Set 6 | alofi
# Processing Record 9 of Set 6 | yueyang
# Processing Record 10 of Set 6 | constitucion
# Processing Record 11 of Set 6 | cherskiy
# Processing Record 12 of Set 6 | puliyur
# Processing Record 13 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 14 of Set 6 | kaitangata
# Processing Record 15 of Set 6 | buchanan
# Processing Record 16 of Set 6 | muisne
# Processing Record 17 of Set 6 | utevka
# Processing Record 18 of Set 6 | port moresby
# Processing Record 19 of Set 6 | pendleton
# Processing Record 20 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 21 of Set 6 | shahr-e babak
# Processing Record 22 of Set 6 | ranghulu
# Processing Record 23 of Set 6 | viedma
# Processing Record 24 of Set 6 | bahia honda
# Processing Record 25 of Set 6 | manyana
# Processing Record 26 of Set 6 | killybegs
# Processing Record 27 of Set 6 | kavieng
# Processing Record 28 of Set 6 | barsovo
# Processing Record 29 of Set 6 | segamat
# Processing Record 30 of Set 6 | dingle
# Processing Record 31 of Set 6 | itarema
# Processing Record 32 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 33 of Set 6 | tuatapere
# Processing Record 34 of Set 6 | souillac
# Processing Record 35 of Set 6 | wanning
# Processing Record 36 of Set 6 | yaan
# Processing Record 37 of Set 6 | cockburn town
# Processing Record 38 of Set 6 | saldanha
# Processing Record 39 of Set 6 | antofagasta
# Processing Record 40 of Set 6 | vanimo
# Processing Record 41 of Set 6 | yeroham
# Processing Record 42 of Set 6 | hammerfest
# Processing Record 43 of Set 6 | sept-iles
# Processing Record 44 of Set 6 | necochea
# Processing Record 45 of Set 6 | gasa
# Processing Record 46 of Set 6 | faanui
# Processing Record 47 of Set 6 | suez
# Processing Record 48 of Set 6 | aybak
# City not found. Skipping...
# Processing Record 49 of Set 6 | mayo
# Processing Record 50 of Set 6 | singapore
# Processing Record 1 of Set 7 | jieshi
# Processing Record 2 of Set 7 | krasnoselkup
# Processing Record 3 of Set 7 | yarim
# Processing Record 4 of Set 7 | norman wells
# Processing Record 5 of Set 7 | conceicao do araguaia
# Processing Record 6 of Set 7 | khromtau
# Processing Record 7 of Set 7 | esmeraldas
# Processing Record 8 of Set 7 | belmonte
# Processing Record 9 of Set 7 | pisco
# Processing Record 10 of Set 7 | gannan
# Processing Record 11 of Set 7 | cabedelo
# Processing Record 12 of Set 7 | turukhansk
# Processing Record 13 of Set 7 | yanan
# City not found. Skipping...
# Processing Record 14 of Set 7 | pundaguitan
# Processing Record 15 of Set 7 | yorosso
# Processing Record 16 of Set 7 | dukat
# Processing Record 17 of Set 7 | kolda
# Processing Record 18 of Set 7 | kortkeros
# Processing Record 19 of Set 7 | berlevag
# Processing Record 20 of Set 7 | yulara
# Processing Record 21 of Set 7 | ostrovnoy
# Processing Record 22 of Set 7 | akyab
# Processing Record 23 of Set 7 | bilibino
# Processing Record 24 of Set 7 | arman
# Processing Record 25 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 26 of Set 7 | stornoway
# Processing Record 27 of Set 7 | padang
# Processing Record 28 of Set 7 | lucea
# Processing Record 29 of Set 7 | tabuk
# Processing Record 30 of Set 7 | chaozhou
# Processing Record 31 of Set 7 | brae
# Processing Record 32 of Set 7 | tambo
# Processing Record 33 of Set 7 | guerrero negro
# Processing Record 34 of Set 7 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 35 of Set 7 | bermeo
# Processing Record 36 of Set 7 | ossora
# Processing Record 37 of Set 7 | mozarlandia
# Processing Record 38 of Set 7 | olafsvik
# Processing Record 39 of Set 7 | mahajanga
# Processing Record 40 of Set 7 | poronaysk
# Processing Record 41 of Set 7 | kalemie
# Processing Record 42 of Set 7 | lundazi
# Processing Record 43 of Set 7 | manjacaze
# Processing Record 44 of Set 7 | batticaloa
# Processing Record 45 of Set 7 | yar-sale
# Processing Record 46 of Set 7 | coihaique
# Processing Record 47 of Set 7 | zafra
# Processing Record 48 of Set 7 | port lincoln
# Processing Record 49 of Set 7 | tateyama
# Processing Record 50 of Set 7 | chuy
# Processing Record 1 of Set 8 | saint-pierre
# Processing Record 2 of Set 8 | grand-lahou
# Processing Record 3 of Set 8 | skibbereen
# Processing Record 4 of Set 8 | mount isa
# Processing Record 5 of Set 8 | sokoto
# Processing Record 6 of Set 8 | airai
# Processing Record 7 of Set 8 | beian
# Processing Record 8 of Set 8 | scottsburgh
# City not found. Skipping...
# Processing Record 9 of Set 8 | udachnyy
# Processing Record 10 of Set 8 | sibenik
# Processing Record 11 of Set 8 | takhtamygda
# Processing Record 12 of Set 8 | de-kastri
# Processing Record 13 of Set 8 | mehamn
# Processing Record 14 of Set 8 | tongliao
# Processing Record 15 of Set 8 | cidreira
# Processing Record 16 of Set 8 | angra
# City not found. Skipping...
# Processing Record 17 of Set 8 | broome
# Processing Record 18 of Set 8 | nobeoka
# Processing Record 19 of Set 8 | nome
# Processing Record 20 of Set 8 | asfi
# Processing Record 21 of Set 8 | kampene
# Processing Record 22 of Set 8 | maarianhamina
# Processing Record 23 of Set 8 | plettenberg bay
# Processing Record 24 of Set 8 | sataua
# City not found. Skipping...
# Processing Record 25 of Set 8 | te anau
# Processing Record 26 of Set 8 | leningradskiy
# Processing Record 27 of Set 8 | juifang
# City not found. Skipping...
# Processing Record 28 of Set 8 | tommot
# Processing Record 29 of Set 8 | yomitan
# City not found. Skipping...
# Processing Record 30 of Set 8 | nikolsk
# Processing Record 31 of Set 8 | ilulissat
# Processing Record 32 of Set 8 | yamada
# Processing Record 33 of Set 8 | klaksvik
# Processing Record 34 of Set 8 | coreau
# Processing Record 35 of Set 8 | deputatskiy
# Processing Record 36 of Set 8 | diban
# Processing Record 37 of Set 8 | urengoy
# Processing Record 38 of Set 8 | hirara
# Processing Record 39 of Set 8 | mae chan
# Processing Record 40 of Set 8 | mustafabad
# Processing Record 41 of Set 8 | helong
# Processing Record 42 of Set 8 | havre-saint-pierre
# Processing Record 43 of Set 8 | bambanglipuro
# Processing Record 44 of Set 8 | hambantota
# Processing Record 45 of Set 8 | victor harbor
# Processing Record 46 of Set 8 | vestmanna
# Processing Record 47 of Set 8 | dalby
# Processing Record 48 of Set 8 | sindor
# Processing Record 49 of Set 8 | kedrovyy
# Processing Record 50 of Set 8 | osmaniye
# Processing Record 1 of Set 9 | santiago del estero
# Processing Record 2 of Set 9 | saint-georges
# Processing Record 3 of Set 9 | lebyazhye
# Processing Record 4 of Set 9 | tiznit
# Processing Record 5 of Set 9 | mount pleasant
# Processing Record 6 of Set 9 | teya
# Processing Record 7 of Set 9 | putina
# Processing Record 8 of Set 9 | orlik
# Processing Record 9 of Set 9 | sawang daen din
# Processing Record 10 of Set 9 | terre haute
# Processing Record 11 of Set 9 | umea
# Processing Record 12 of Set 9 | gamba
# Processing Record 13 of Set 9 | lompoc
# Processing Record 14 of Set 9 | richards bay
# Processing Record 15 of Set 9 | dubenskiy
# City not found. Skipping...
# Processing Record 16 of Set 9 | hueytown
# Processing Record 17 of Set 9 | utiroa
# City not found. Skipping...
# Processing Record 18 of Set 9 | sao sepe
# Processing Record 19 of Set 9 | ziarat
# Processing Record 20 of Set 9 | lesnoy
# Processing Record 21 of Set 9 | gold coast
# Processing Record 22 of Set 9 | skalistyy
# City not found. Skipping...
# Processing Record 23 of Set 9 | mago
# Processing Record 24 of Set 9 | cabo san lucas
# Processing Record 25 of Set 9 | harper
# Processing Record 26 of Set 9 | kudat
# Processing Record 27 of Set 9 | bogovarovo
# Processing Record 28 of Set 9 | providencia
# Processing Record 29 of Set 9 | port blair
# Processing Record 30 of Set 9 | salalah
# Processing Record 31 of Set 9 | supaul
# Processing Record 32 of Set 9 | anadyr
# Processing Record 33 of Set 9 | beaufort
# Processing Record 34 of Set 9 | namatanai
# Processing Record 35 of Set 9 | nishihara
# Processing Record 36 of Set 9 | banda aceh
# Processing Record 37 of Set 9 | cayenne
# Processing Record 38 of Set 9 | cozumel
# Processing Record 39 of Set 9 | faya
# Processing Record 40 of Set 9 | mackay
# Processing Record 41 of Set 9 | dos hermanas
# Processing Record 42 of Set 9 | port macquarie
# Processing Record 43 of Set 9 | vryburg
# Processing Record 44 of Set 9 | tual
# Processing Record 45 of Set 9 | challans
# Processing Record 46 of Set 9 | naze
# Processing Record 47 of Set 9 | homer
# Processing Record 48 of Set 9 | ugoofaaru
# Processing Record 49 of Set 9 | tilichiki
# Processing Record 50 of Set 9 | bam
# Processing Record 1 of Set 10 | olga
# Processing Record 2 of Set 10 | stokmarknes
# Processing Record 3 of Set 10 | ziyamet
# City not found. Skipping...
# Processing Record 4 of Set 10 | barranca
# Processing Record 5 of Set 10 | clonakilty
# Processing Record 6 of Set 10 | biak
# Processing Record 7 of Set 10 | dzhusaly
# City not found. Skipping...
# Processing Record 8 of Set 10 | ewa beach
# Processing Record 9 of Set 10 | umtata
# Processing Record 10 of Set 10 | uniontown
# Processing Record 11 of Set 10 | flin flon
# Processing Record 12 of Set 10 | nioro
# Processing Record 13 of Set 10 | parati
# Processing Record 14 of Set 10 | tyumentsevo
# Processing Record 15 of Set 10 | gat
# Processing Record 16 of Set 10 | acapulco
# Processing Record 17 of Set 10 | lamu
# Processing Record 18 of Set 10 | koungou
# Processing Record 19 of Set 10 | hollola
# Processing Record 20 of Set 10 | anqing
# Processing Record 21 of Set 10 | bhikangaon
# Processing Record 22 of Set 10 | turayf
# Processing Record 23 of Set 10 | verkhnetulomskiy
# Processing Record 24 of Set 10 | yerbogachen
# Processing Record 25 of Set 10 | paradwip
# City not found. Skipping...
# Processing Record 26 of Set 10 | usinsk
# Processing Record 27 of Set 10 | nago
# Processing Record 28 of Set 10 | dekar
# Processing Record 29 of Set 10 | college
# Processing Record 30 of Set 10 | japura
# Processing Record 31 of Set 10 | namibe
# Processing Record 32 of Set 10 | kefamenanu
# Processing Record 33 of Set 10 | nikki
# Processing Record 34 of Set 10 | gornopravdinsk
# Processing Record 35 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 36 of Set 10 | pringsewu
# Processing Record 37 of Set 10 | poum
# Processing Record 38 of Set 10 | kismayo
# Processing Record 39 of Set 10 | nevelsk
# Processing Record 40 of Set 10 | praia da vitoria
# Processing Record 41 of Set 10 | remanso
# Processing Record 42 of Set 10 | seoul
# Processing Record 43 of Set 10 | arlit
# Processing Record 44 of Set 10 | bushehr
# Processing Record 45 of Set 10 | shenjiamen
# Processing Record 46 of Set 10 | russkiy
# Processing Record 47 of Set 10 | baykit
# Processing Record 48 of Set 10 | avera
# Processing Record 49 of Set 10 | iqaluit
# Processing Record 50 of Set 10 | vagur
# Processing Record 1 of Set 11 | aldan
# Processing Record 2 of Set 11 | camana
# Processing Record 3 of Set 11 | saryozek
# Processing Record 4 of Set 11 | nelson bay
# Processing Record 5 of Set 11 | sur
# Processing Record 6 of Set 11 | huanren
# Processing Record 7 of Set 11 | santa fe
# Processing Record 8 of Set 11 | siva
# Processing Record 9 of Set 11 | ballina
# Processing Record 10 of Set 11 | lokosovo
# Processing Record 11 of Set 11 | mount gambier
# Processing Record 12 of Set 11 | zhenlai
# Processing Record 13 of Set 11 | medicine hat
# Processing Record 14 of Set 11 | karamea
# City not found. Skipping...
# Processing Record 15 of Set 11 | fare
# Processing Record 16 of Set 11 | marawi
# Processing Record 17 of Set 11 | kavaratti
# Processing Record 18 of Set 11 | abu zabad
# Processing Record 19 of Set 11 | porbandar
# Processing Record 20 of Set 11 | spearfish
# Processing Record 21 of Set 11 | canavieiras
# Processing Record 22 of Set 11 | verkhnevilyuysk
# Processing Record 23 of Set 11 | mattru
# Processing Record 24 of Set 11 | sturgis
# Processing Record 25 of Set 11 | kieta
# Processing Record 26 of Set 11 | urumqi
# Processing Record 27 of Set 11 | mazyr
# Processing Record 28 of Set 11 | bressuire
# Processing Record 29 of Set 11 | petrolandia
# City not found. Skipping...
# Processing Record 30 of Set 11 | caronport
# Processing Record 31 of Set 11 | torbay
# Processing Record 32 of Set 11 | hokitika
# Processing Record 33 of Set 11 | pacific grove
# Processing Record 34 of Set 11 | rio do sul
# Processing Record 35 of Set 11 | khonuu
# City not found. Skipping...
# Processing Record 36 of Set 11 | san carlos de bariloche
# Processing Record 37 of Set 11 | luangwa
# Processing Record 38 of Set 11 | freeport
# Processing Record 39 of Set 11 | huaihua
# Processing Record 40 of Set 11 | hamilton
# Processing Record 41 of Set 11 | bangkok
# Processing Record 42 of Set 11 | axim
# Processing Record 43 of Set 11 | yumen
# Processing Record 44 of Set 11 | cuamba
# Processing Record 45 of Set 11 | chau doc
# Processing Record 46 of Set 11 | la ligua
# Processing Record 47 of Set 11 | hovd
# Processing Record 48 of Set 11 | port-cartier
# Processing Record 49 of Set 11 | ostersund
# Processing Record 50 of Set 11 | preeceville
# Processing Record 1 of Set 12 | sola
# Processing Record 2 of Set 12 | berbera
# Processing Record 3 of Set 12 | puerto leguizamo
# Processing Record 4 of Set 12 | kaili
# Processing Record 5 of Set 12 | dicabisagan
# Processing Record 6 of Set 12 | beira
# Processing Record 7 of Set 12 | amapa
# Processing Record 8 of Set 12 | muli
# Processing Record 9 of Set 12 | atar
# Processing Record 10 of Set 12 | peniche
# Processing Record 11 of Set 12 | esna
# Processing Record 12 of Set 12 | zhob
# Processing Record 13 of Set 12 | susanville
# Processing Record 14 of Set 12 | ulaangom
# Processing Record 15 of Set 12 | tiarei
# Processing Record 16 of Set 12 | raudeberg
# Processing Record 17 of Set 12 | acarau
# Processing Record 18 of Set 12 | bokovskaya
# Processing Record 19 of Set 12 | sanming
# Processing Record 20 of Set 12 | aykhal
# Processing Record 21 of Set 12 | oldebroek
# Processing Record 22 of Set 12 | otuzco
# Processing Record 23 of Set 12 | galgani
# City not found. Skipping...
# Processing Record 24 of Set 12 | kralendijk
# Processing Record 25 of Set 12 | puerto escondido
# Processing Record 26 of Set 12 | ust-omchug
# Processing Record 27 of Set 12 | kenai
# Processing Record 28 of Set 12 | grass valley
# Processing Record 29 of Set 12 | manado
# Processing Record 30 of Set 12 | kholmogory
# Processing Record 31 of Set 12 | kutum
# Processing Record 32 of Set 12 | togur
# Processing Record 33 of Set 12 | juneau
# Processing Record 34 of Set 12 | grande prairie
# Processing Record 35 of Set 12 | cam ranh
# Processing Record 36 of Set 12 | progreso
# Processing Record 37 of Set 12 | sulangan
# Processing Record 38 of Set 12 | hami
# Processing Record 39 of Set 12 | kangaatsiaq
# Processing Record 40 of Set 12 | darhan
# Processing Record 41 of Set 12 | redlands
# Processing Record 42 of Set 12 | gagino
# Processing Record 43 of Set 12 | itupiranga
# Processing Record 44 of Set 12 | ixtapa
# Processing Record 45 of Set 12 | ijaki
# City not found. Skipping...
# Processing Record 46 of Set 12 | itoman
# Processing Record 47 of Set 12 | karpogory
# Processing Record 48 of Set 12 | annonay
# Processing Record 49 of Set 12 | xixiang
# Processing Record 50 of Set 12 | labuhan
# Processing Record 1 of Set 13 | zeya
# Processing Record 2 of Set 13 | temir
# Processing Record 3 of Set 13 | ponta delgada
# Processing Record 4 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 5 of Set 13 | cockburn harbour
# City not found. Skipping...
# Processing Record 6 of Set 13 | dubbo
# Processing Record 7 of Set 13 | narasaraopet
# Processing Record 8 of Set 13 | plastun
# Processing Record 9 of Set 13 | borogontsy
# Processing Record 10 of Set 13 | ust-nera
# Processing Record 11 of Set 13 | marystown
# Processing Record 12 of Set 13 | belyy yar
# Processing Record 13 of Set 13 | labelle
# Processing Record 14 of Set 13 | nova soure
# Processing Record 15 of Set 13 | lagoa
# Processing Record 16 of Set 13 | beloha
# Processing Record 17 of Set 13 | kashi
# Processing Record 18 of Set 13 | shelburne
# Processing Record 19 of Set 13 | smithers
# Processing Record 20 of Set 13 | bargal
# City not found. Skipping...
# Processing Record 21 of Set 13 | tahoua
# Processing Record 22 of Set 13 | chumikan
# Processing Record 23 of Set 13 | hatillo
# Processing Record 24 of Set 13 | rundu
# Processing Record 25 of Set 13 | connersville
# Processing Record 26 of Set 13 | aksarka
# Processing Record 27 of Set 13 | wahran
# City not found. Skipping...
# Processing Record 28 of Set 13 | bari
# Processing Record 29 of Set 13 | kudahuvadhoo
# Processing Record 30 of Set 13 | saint anthony
# Processing Record 31 of Set 13 | broken hill
# Processing Record 32 of Set 13 | labrea
# Processing Record 33 of Set 13 | fernandina beach
# Processing Record 34 of Set 13 | beringovskiy
# Processing Record 35 of Set 13 | grindavik
# Processing Record 36 of Set 13 | chara
# Processing Record 37 of Set 13 | campo verde
# Processing Record 38 of Set 13 | west wendover
# Processing Record 39 of Set 13 | waipawa
# Processing Record 40 of Set 13 | havelock
# Processing Record 41 of Set 13 | monte alegre
# Processing Record 42 of Set 13 | dvinskoy
# Processing Record 43 of Set 13 | bardiyah
# Processing Record 44 of Set 13 | hofn
# Processing Record 45 of Set 13 | divo
# Processing Record 46 of Set 13 | teknaf
# Processing Record 47 of Set 13 | algeciras
# Processing Record 48 of Set 13 | ndele
# Processing Record 49 of Set 13 | binghamton
# Processing Record 50 of Set 13 | tabulbah
# City not found. Skipping...
# Processing Record 1 of Set 14 | eenhana
# Processing Record 2 of Set 14 | sindand
# City not found. Skipping...
# Processing Record 3 of Set 14 | khunzakh
# Processing Record 4 of Set 14 | maldonado
# Processing Record 5 of Set 14 | moindou
# Processing Record 6 of Set 14 | ihosy
# Processing Record 7 of Set 14 | quelimane
# Processing Record 8 of Set 14 | palmer
# Processing Record 9 of Set 14 | belokurikha
# Processing Record 10 of Set 14 | goderich
# Processing Record 11 of Set 14 | gaozhou
# Processing Record 12 of Set 14 | zhitikara
# City not found. Skipping...
# Processing Record 13 of Set 14 | skerries
# Processing Record 14 of Set 14 | benjamin hill
# Processing Record 15 of Set 14 | hamada
# Processing Record 16 of Set 14 | oranjemund
# Processing Record 17 of Set 14 | chicama
# Processing Record 18 of Set 14 | lumding
# Processing Record 19 of Set 14 | winnemucca
# Processing Record 20 of Set 14 | ambodifototra
# City not found. Skipping...
# Processing Record 21 of Set 14 | oranjestad
# Processing Record 22 of Set 14 | sibolga
# Processing Record 23 of Set 14 | les cayes
# Processing Record 24 of Set 14 | babanusah
# City not found. Skipping...
# Processing Record 25 of Set 14 | moree
# Processing Record 26 of Set 14 | nguiu
# City not found. Skipping...
# Processing Record 27 of Set 14 | campbellsville
# Processing Record 28 of Set 14 | kimbe
# Processing Record 29 of Set 14 | chiredzi
# Processing Record 30 of Set 14 | sao joao del rei
# Processing Record 31 of Set 14 | mackenzie
# Processing Record 32 of Set 14 | kemijarvi
# Processing Record 33 of Set 14 | washington
# Processing Record 34 of Set 14 | nenjiang
# Processing Record 35 of Set 14 | sabha
# Processing Record 36 of Set 14 | santa vitoria do palmar
# Processing Record 37 of Set 14 | kachiry
# Processing Record 38 of Set 14 | lazaro cardenas
# Processing Record 39 of Set 14 | jasper
# Processing Record 40 of Set 14 | muros
# Processing Record 41 of Set 14 | hua hin
# Processing Record 42 of Set 14 | zyryanka
# Processing Record 43 of Set 14 | zavyalovo
# Processing Record 44 of Set 14 | jumla
# Processing Record 45 of Set 14 | buraydah
# Processing Record 46 of Set 14 | kazalinsk
# City not found. Skipping...
# Processing Record 47 of Set 14 | enshi
# Processing Record 48 of Set 14 | eyl
# Processing Record 49 of Set 14 | tacotalpa
# Processing Record 50 of Set 14 | naranjito
# Processing Record 1 of Set 15 | rawson
# Processing Record 2 of Set 15 | tukrah
# Processing Record 3 of Set 15 | tarudant
# City not found. Skipping...
# Processing Record 4 of Set 15 | kohlu
# Processing Record 5 of Set 15 | puerto carreno
# Processing Record 6 of Set 15 | caledon
# Processing Record 7 of Set 15 | leshukonskoye
# Processing Record 8 of Set 15 | pangkalanbuun
# Processing Record 9 of Set 15 | ilhabela
# Processing Record 10 of Set 15 | manaure
# Processing Record 11 of Set 15 | orange cove
# Processing Record 12 of Set 15 | clayton
# Processing Record 13 of Set 15 | nhulunbuy
# Processing Record 14 of Set 15 | lapua
# Processing Record 15 of Set 15 | las cruces
# Processing Record 16 of Set 15 | semey
# Processing Record 17 of Set 15 | bath
# Processing Record 18 of Set 15 | itai
# Processing Record 19 of Set 15 | lithakia
# Processing Record 20 of Set 15 | bodden town
# Processing Record 21 of Set 15 | kijang
# Processing Record 22 of Set 15 | illela
# Processing Record 23 of Set 15 | bolungarvik
# City not found. Skipping...
# Processing Record 24 of Set 15 | merauke
# Processing Record 25 of Set 15 | kuhestan
# City not found. Skipping...
# Processing Record 26 of Set 15 | sangar
# Processing Record 27 of Set 15 | yunjinghong
# City not found. Skipping...
# Processing Record 28 of Set 15 | polson
# Processing Record 29 of Set 15 | pangai
# Processing Record 30 of Set 15 | ifakara
# Processing Record 31 of Set 15 | gao
# Processing Record 32 of Set 15 | riyadh
# Processing Record 33 of Set 15 | lang son
# Processing Record 34 of Set 15 | timizart
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Dedza      MW -14.3779   34.3332     63.66        42           7
# 1           Ola      RU  59.5833  151.2833     49.26        78          93
# 2  San Patricio      US  28.0170  -97.5169     91.81        63          98
# 3  Saint George      US  37.1041 -113.5841    100.87        11           1
# 4      Khatanga      RU  71.9667  102.5000     40.24        94         100
# 5       Ushuaia      AR -54.8000  -68.3000     28.06        93          96
# 6  Punta Arenas      CL -53.1500  -70.9167     39.31        52          75
# 7     Busselton      AU -33.6500  115.3333     50.09        77          56
# 8         Arawa      PG  -6.2132  155.5367     78.49        82          72
# 9         Sitka      US  57.0531 -135.3300     53.49        76          90
#
#    Wind Speed Current Description
# 0        1.36           clear sky
# 1        5.97     overcast clouds
# 2        7.36     overcast clouds
# 3        3.00           clear sky
# 4        9.66     overcast clouds
# 5       26.46          light snow
# 6       23.02       broken clouds
# 7       22.73          light rain
# 8        3.13       broken clouds
# 9        8.05          light rain

# %%
new_column_order = ["City", "Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_df_2 = city_data_df[new_column_order]
city_data_df_2.head()
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Dedza      MW -14.3779   34.3332     63.66        42           7
# 1           Ola      RU  59.5833  151.2833     49.26        78          93
# 2  San Patricio      US  28.0170  -97.5169     91.81        63          98
# 3  Saint George      US  37.1041 -113.5841    100.87        11           1
# 4      Khatanga      RU  71.9667  102.5000     40.24        94         100
#
#    Wind Speed Current Description
# 0        1.36           clear sky
# 1        5.97     overcast clouds
# 2        7.36     overcast clouds
# 3        3.00           clear sky
# 4        9.66     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df_2.to_csv(output_data_file, index_label="City_ID")
